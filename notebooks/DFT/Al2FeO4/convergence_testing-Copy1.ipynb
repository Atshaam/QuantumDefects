# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ENCUT = np.linspace(300, 950,14)
energy = [-3.76477756, -3.76571668, -3.76599853, -3.766679815, -3.766831305, -3.76694684, -3.766994975, -3.766996905, -3.76705285, -3.767078415, -3.767097725,-3.7671047, -3.767101905, -3.767104635]

# %%
for i in range(len(energy)):
    energy[i] = (energy[i] * 1000) + 3767.105

# %%
print(ENCUT)
# Out:
# [300. 350. 400. 450. 500. 550. 600. 650. 700. 750. 800. 850. 900. 950.]

# %%
print(energy)
# Out:
# [-3761006687.895, -3761945807.895, -3762227657.895, -3762908942.895, -3763060432.895, -3763175967.895, -3763224102.8949995, -3763226032.895, -3763281977.8949995, -3763307542.895, -3763326852.895, -3763333827.8949995, -3763331032.895, -3763333762.8950005]

# %%
fig, ax = plt.subplots()
ax.plot(ENCUT, energy, marker='x')  # Assuming you have these lists already
ax.hlines(0, 299, 950, colors='orange', linestyle='dashed')
# Add labels on top of each bar
ax.set_xlabel("ENCUT (eV)")
ax.set_ylabel("Energy relative to Convergence Value (meV / atom)")
plt.tight_layout()

plt.show()

# %% [markdown]
# Convergence to 0.005 eV at ENCUT = 300?
# KPOINTS: ENCUT = 550

# %%
cutoff = [4.666, 6.221, 7.776, 9.331, 10.886, 12.442, 13.997, 15.552]
KPOINTS = [3,4,5,6,7,8,9,10]
energy_kpoint = [-3.6746106, -3.76694684, -3.786398995, -3.791158615, -3.79248486, -3.792772185, -3.79285828, -3.792899275]

# %%
for i in range(len(energy_kpoint)):
    energy_kpoint[i] = (energy_kpoint[i] * 1000) + 3792.90

# %%
fig, ax = plt.subplots()
ax.plot(KPOINTS, energy_kpoint, marker = 'x')  # Assuming you have these lists already
ax.hlines(0, 3, 10, colors='orange', linestyle='dashed')
# Add labels on top of each bar
ax.set_xlabel("Number of k-points")
ax.set_ylabel("Energy relative to Convergence Value (meV / atom)")
plt.tight_layout()

plt.show()
