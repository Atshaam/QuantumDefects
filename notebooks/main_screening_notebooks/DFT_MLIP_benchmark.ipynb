# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Sample Data ---
# Replace this mock data with your actual lists/dictionaries of energies/values
# materials = ['AlClO', 'Al2FeO4', 'Al2(SO4)3', 'LiAlO2', 'BeAl2O4']

# # Data for the three comparison categories (e.g., three different models or DFT vs two MLIPs)
# data_set_1 = [-0.032, -2.291, -0.057, -0.001, -0.025]  # Example: Primitive diff wrt DFT
# data_set_2 = [-0.294, 2.731, -0.115,  0.062, -0.046]  # Example: MLFF Bulk supercell wrt DFT
# data_set_3 = [-0.169, 2.85, 0.054, -0.803, -0.141, ]  # Example: MLFF Model B Energy

materials = ['AlClO', 'Al2(SO4)3', 'LiAlO2', 'BeAl2O4']

# Data for the three comparison categories (e.g., three different models or DFT vs two MLIPs)
data_set_1 = [-0.032, -0.057, -0.001, -0.025]  # Example: Primitive diff wrt DFT
data_set_2 = [-0.294, -0.115,  0.062, -0.046]  # Example: MLFF Bulk supercell wrt DFT
data_set_3 = [-0.169, 0.054, -0.803, -0.141, ]  # Example: MLFF Model B Energy
data_set_4 = []
data_set_5 = []

# Labels for the three data sets
label_1 = 'Primitive Cell Relaxation'
label_2 = 'Host Supercell Relaxation'
label_3 = 'Defect Supercell Relaxation'
label_4 = 'Al Chemcal Potential'
label_5 = 'Cr Chemical Potential'

# --- 2. Setup Plotting Parameters ---
x = np.arange(len(materials))  # the label locations (0, 1, 2, 3...)
width = 0.25  # the width of the bars

# Create the figure and the axes
fig, ax = plt.subplots(figsize=(10, 6))

# --- 3. Plot the three groups of bars ---

# Set 1 (Left bar) - Shifted left by 1.5 bar widths
rects1 = ax.bar(x - width, data_set_1, width, label=label_1, color='#1f77b4')

# Set 2 (Center bar) - Centered on the tick mark
rects2 = ax.bar(x, data_set_2, width, label=label_2, color='#ff7f0e')

# Set 3 (Right bar) - Shifted right by 1.5 bar widths
rects3 = ax.bar(x + width, data_set_3, width, label=label_3, color='#2ca02c')


# --- 4. Customize and Label ---

# Add some text for labels, title, and custom x-axis tick labels
ax.set_ylabel('Energy Difference wrt to DFT(eV)')
# ax.set_title('MLFF Defect Formation Energy Comparison with DFT by Material and Type of Calculation')
ax.set_xticks(x)
ax.set_xticklabels(materials, fontsize=14)
ax.legend()

# Add a horizontal line at y=0 if the data includes negative values
ax.axhline(0, color='gray', linestyle='--') 
plt.ylim(-0.81, 0.81)
# Adjust layout to prevent labels from being cut off
fig.tight_layout()
# plt.savefig('../figures/uma/benchmark_DFT2.png')
# Display the plot
plt.show()
